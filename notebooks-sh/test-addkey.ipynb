# %%
import pandas as pd
import numpy as np

# %%
eeg = np.load('../data/processed/eeg_specs.npy',allow_pickle=True).item()

# %%
len(eeg)
# Out:
# 18013

# %%
eeg['568657Other']
# Out:
# array([[[-21.752737 , -25.707153 , -11.53628  , -23.299295 ],
#         [-16.300549 , -21.857933 ,  -5.988491 , -19.741318 ],
#         [-16.35944  , -16.290432 ,  -6.2337093, -14.625044 ],
#         ...,
#         [-22.15362  ,  -4.6156445, -11.683958 , -13.677179 ],
#         [-21.2791   ,  -5.746958 ,  -7.408785 , -12.2544   ],
#         [-16.11554  ,  -6.9283657,  -8.377289 , -12.305471 ]],
#
#        [[-21.80134  , -25.752842 , -11.593544 , -23.35785  ],
#         [-16.4502   , -21.084732 ,  -6.129137 , -18.780245 ],
#         [-16.551405 , -16.354042 ,  -6.4004803, -14.785126 ],
#         ...,
#         [-21.683718 ,  -4.7568493, -10.798432 , -13.827528 ],
#         [-20.589128 ,  -5.913067 ,  -7.5642834, -12.37985  ],
#         [-16.210602 ,  -7.113476 ,  -8.49872  , -12.463099 ]],
#
#        [[-21.864609 , -25.812628 , -11.668383 , -23.434513 ],
#         [-16.646935 , -20.650108 ,  -6.313387 , -18.268646 ],
#         [-16.805567 , -16.445795 ,  -6.619068 , -14.996033 ],
# ...

# %%
## download eeg

eeg_download = np.load('../data/download/eeg_specs.npy', allow_pickle=True).item()

eeg_download
# Out:
# {1628180742: array([[[ 3.99143636e-01,  5.66232622e-01,  6.20352149e-01,
#            2.25220025e-01],
#          [ 5.87142587e-01,  6.53478444e-01,  7.50046134e-01,
#            4.33759660e-01],
#          [ 6.41346753e-01,  6.95377648e-01,  7.25210190e-01,
#            3.70616108e-01],
#          ...,
#          [ 7.52772331e-01,  7.71488130e-01,  7.01473653e-01,
#            5.27046859e-01],
#          [ 7.38201439e-01,  6.92762792e-01,  6.93909287e-01,
#            4.95433450e-01],
#          [ 7.01915145e-01,  8.00927997e-01,  7.38896847e-01,
#            4.82495129e-01]],
#
#         [[ 4.09951359e-01,  5.65765440e-01,  6.19208515e-01,
#            2.22650066e-01],
#          [ 5.83659232e-01,  6.50360167e-01,  7.46591806e-01,
#            4.31236088e-01],
#          [ 6.37223721e-01,  6.97596073e-01,  7.21317768e-01,
#            3.87780428e-01],
#          ...,
#          [ 7.48578429e-01,  7.72669077e-01,  6.99848831e-01,
#            5.23570478e-01],
# ...

# %%
eeg_download[568657]
# Out:
# array([[[ 0.4561816 ,  0.35732108,  0.71159285,  0.41751745],
#         [ 0.59248626,  0.4535516 ,  0.8502876 ,  0.506467  ],
#         [ 0.5910139 ,  0.5927391 ,  0.8441572 ,  0.63437384],
#         ...,
#         [ 0.44615948,  0.88460886,  0.707901  ,  0.65807045],
#         [ 0.4680224 ,  0.8563259 ,  0.8147803 ,  0.69363993],
#         [ 0.59711146,  0.82679087,  0.7905678 ,  0.6923631 ]],
#
#        [[ 0.45496643,  0.35617894,  0.7101613 ,  0.4160537 ],
#         [ 0.588745  ,  0.4728817 ,  0.8467715 ,  0.53049374],
#         [ 0.5862148 ,  0.59114873,  0.8399879 ,  0.6303718 ],
#         ...,
#         [ 0.45790696,  0.88107866,  0.7300392 ,  0.65431166],
#         [ 0.4852717 ,  0.85217315,  0.81089294,  0.6905036 ],
#         [ 0.59473497,  0.8221631 ,  0.787532  ,  0.68842256]],
#
#        [[ 0.45338464,  0.3546843 ,  0.70829034,  0.41413707],
#         [ 0.58382654,  0.4837472 ,  0.84216505,  0.5432838 ],
#         [ 0.5798607 ,  0.588855  ,  0.8345232 ,  0.6250992 ],
# ...
